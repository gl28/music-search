# %%
import sqlite3
import os
import openai
import time
import datetime
import chromadb

openai.api_key = os.getenv("OPENAI_API_KEY")
SQLITE_DB_NAME = "../data/reviews_database.sqlite"

# %%
# create the DB table which we're going to used for the compressed reviews
conn = sqlite3.connect(SQLITE_DB_NAME)
cursor = conn.cursor()

cursor.execute(
            """
            CREATE TABLE IF NOT EXISTS compressed_content (
                reviewId INTEGER PRIMARY KEY,
                complete_content TEXT NOT NULL,
                vibes TEXT NOT NULL,
                genres TEXT NOT NULL,
                instruments TEXT NOT NULL
            )
            """
        )

conn.close()

# %%
# call ChatGPT and ask it to extract descriptive content from the review
def get_compressed_review(review):
  system_prompt = """You will be given an album review. Read the review and extract any words or phrases that describe the music itself or its emotions/vibes.
  
  Your response should be formatted like this:
  
  INSTRUMENTS: <description of instruments
  GENRES: <list of genres
  EMOTIONS/VIBES: <description of emotions/vibes>
  Do not use full sentences or punctuation."""

  response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
          {"role": "system", "content": system_prompt},
          {"role": "user", "content": review},
      ],
    temperature=0.6,
    max_tokens=256
  )

  return response.choices[0].message.content

# parse the compressed review into the correct sections and return it as a dictionary
def parse_compressed_review(review):
  lines = review.strip().split('\n')
  parsed_review = {}
  for line in lines:
    section, content = line.split(':', 1)
    parsed_review[section.strip().lower()] = content.strip()
  
  return parsed_review

# %%
conn = sqlite3.connect(SQLITE_DB_NAME)
cursor = conn.cursor()

# make a set of reviewIds that have already been processed so we can easily skip them if
# the script fails part way through and needs to be restarted. it's a bit hacky but ¯\_(ツ)_/¯
cursor.execute("SELECT reviewId FROM compressed_content")
review_id_rows = cursor.fetchall()
review_id_set = set(row[0] for row in review_id_rows)

cursor.execute("SELECT reviewId, content FROM content")
rows = cursor.fetchall()

for row in rows[0:3]:
    print(row)


cursor.execute("SELECT * FROM compressed_content")
rows = cursor.fetchall()

for row in rows[0:3]:
    print(row)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 6
#       2 cursor = conn.cursor()
#       4 # make a set of reviewIds that have already been processed so we can easily skip them if
#       5 # the script fails part way through and needs to be restarted. it's a bit hacky but ¯\_(ツ)_/¯
# ----> 6 cursor.execute("SELECT reviewId FROM compressed_content")
#       7 review_id_rows = cursor.fetchall()
#       8 review_id_set = set(row[0] for row in review_id_rows)
#
# OperationalError: no such table: compressed_content

# %%
conn = sqlite3.connect(SQLITE_DB_NAME)
cursor = conn.cursor()

# make a set of reviewIds that have already been processed so we can easily skip them if
# the script fails part way through and needs to be restarted. it's a bit hacky but ¯\_(ツ)_/¯
cursor.execute("SELECT reviewId FROM compressed_content")
review_id_rows = cursor.fetchall()
review_id_set = set(row[0] for row in review_id_rows)

cursor.execute("SELECT reviewId, content FROM content")
rows = cursor.fetchall()

start_time = time.time()

# get/parse compressed reviews for each review
for i, row in enumerate(rows):
    review_id, review = row
    if review_id in review_id_set:
        print(f"Skipping reviewId {review_id}")
        continue

    elapsed_time = time.time() - start_time
    elapsed_time_str = str(datetime.timedelta(seconds=elapsed_time))
    print(f"Index {i}/{len(rows)}. Elapsed time: {elapsed_time_str}.")

    try:
        # have GPT compress the review
        print(f"Compressing reviewId {review_id} with content {review}")
        compressed_review = get_compressed_review(review)
        print(f"Finished compressing reviewId {review_id}: {compressed_review}")

        # parse it
        parsed_review = parse_compressed_review(compressed_review)
        print(f"Finished parsing reviewId {review_id}: {parsed_review}")
        vibes = parsed_review["emotions/vibes"]
        genres = parsed_review["genres"]
        instruments = parsed_review["instruments"]
        complete_content = f"{genres}, {vibes}, {instruments}"

        # store it
        cursor.execute("""INSERT INTO compressed_content
            (reviewId, complete_content, vibes, genres, instruments)
            VALUES (?, ?, ?, ?, ?)""", (review_id, complete_content, vibes, genres, instruments))
        conn.commit()
    except Exception as e:
        print(f"Error while processing reviewId {review_id}: {e}")
        continue

conn.close()
# Out:
# Skipping reviewId 22703
# Skipping reviewId 22721
# Skipping reviewId 22659
# Skipping reviewId 22661
# Skipping reviewId 22725
# Skipping reviewId 22722
# Skipping reviewId 22704
# Skipping reviewId 22694
# Skipping reviewId 22714
# Skipping reviewId 22724
# Skipping reviewId 22715
# Skipping reviewId 22745
# Skipping reviewId 22700
# Skipping reviewId 22720
# Skipping reviewId 22699
# Skipping reviewId 22665
# Skipping reviewId 22666
# Skipping reviewId 22719
# Skipping reviewId 22667
# Skipping reviewId 22691
# Skipping reviewId 22702
# Skipping reviewId 22718
# Skipping reviewId 22706
# Skipping reviewId 22695
# Skipping reviewId 22713
# Skipping reviewId 22705
# Skipping reviewId 22532
# Skipping reviewId 22701
# Skipping reviewId 22707
# Skipping reviewId 22708
# Skipping reviewId 22559
# Skipping reviewId 22692
# Skipping reviewId 22677
# Skipping reviewId 22469
# Skipping reviewId 22711
# Skipping reviewId 22678
# Skipping reviewId 22664
# Skipping reviewId 22685
# Skipping reviewId 22690
# Skipping reviewId 22689
# Skipping reviewId 22697
# Skipping reviewId 22681
# Skipping reviewId 22698
# Skipping reviewId 22684
# Skipping reviewId 22693
# Skipping reviewId 22686
# Skipping reviewId 22643
# Skipping reviewId 22640
# Skipping reviewId 22688
# Skipping reviewId 22696
# Skipping reviewId 22663
# Skipping reviewId 22687
# Skipping reviewId 22662
# Skipping reviewId 22317
# Skipping reviewId 22673
# Skipping reviewId 22655
# Skipping reviewId 22593
# Skipping reviewId 22627
# Skipping reviewId 22555
# Skipping reviewId 22682
# Skipping reviewId 22679
# Skipping reviewId 22657
# Skipping reviewId 22654
# Skipping reviewId 22631
# Skipping reviewId 22683
# Skipping reviewId 22635
# Skipping reviewId 22653
# Skipping reviewId 22672
# Skipping reviewId 22536
# Skipping reviewId 22676
# Skipping reviewId 22671
# Skipping reviewId 22675
# Skipping reviewId 22680
# Skipping reviewId 22641
# Skipping reviewId 22645
# Skipping reviewId 22393
# Skipping reviewId 22660
# Skipping reviewId 22553
# Skipping reviewId 22626
# Skipping reviewId 22639
# Skipping reviewId 22658
# Skipping reviewId 22638
# Skipping reviewId 22656
# Skipping reviewId 22669
# Skipping reviewId 22634
# Skipping reviewId 19425
# Skipping reviewId 19421
# Skipping reviewId 19424
# Skipping reviewId 19360
# Skipping reviewId 19429
# Skipping reviewId 19401
# Skipping reviewId 19419
# Skipping reviewId 19374
# Skipping reviewId 19380
# Skipping reviewId 19411
# Skipping reviewId 19406
# Skipping reviewId 19375
# Skipping reviewId 19376
# Skipping reviewId 19359
# Skipping reviewId 19403
# Skipping reviewId 19410
# Skipping reviewId 19412
# Skipping reviewId 19288
# Skipping reviewId 19369
# Skipping reviewId 19407
# Skipping reviewId 19405
# Skipping reviewId 19428
# Skipping reviewId 19416
# Skipping reviewId 19304
# Skipping reviewId 19400
# Skipping reviewId 19417
# Skipping reviewId 19404
# Skipping reviewId 19402
# Skipping reviewId 19392
# Skipping reviewId 19302
# Skipping reviewId 19398
# Skipping reviewId 19396
# Skipping reviewId 19310
# Skipping reviewId 19372
# Skipping reviewId 19311
# Skipping reviewId 19377
# Skipping reviewId 19367
# Skipping reviewId 19413
# Skipping reviewId 19339
# Skipping reviewId 19358
# Skipping reviewId 19414
# Skipping reviewId 19383
# Skipping reviewId 19397
# Skipping reviewId 19387
# Skipping reviewId 19384
# Skipping reviewId 19257
# Skipping reviewId 19391
# Skipping reviewId 19349
# Skipping reviewId 19371
# Skipping reviewId 19395
# Skipping reviewId 19297
# Skipping reviewId 19368
# Index 3077/18393. Elapsed time: 0:00:10.793408.
# Compressing reviewId 19092 with content Drop into random sections of the two-and-a-half-hour long block that is 10 Years of Full Pupp and you're liable to hear very different sounds. Some will resemble 1970s psychedelia a la the Steve Miller Band; some the breastbeating passions of Depeche Mode; some New Age, some disco with the flamboyance toned down and sequined unitards replaced by breathable hemp tees. Everything feels engineered for a kind of stoned wonder, like something you might encounter during an evening show at the planetarium.Pigeonholed as "space disco"—a term addressing the idea that this is music people might want to dance or relax to in equal measure—the truth of the music is, as is often the case, messier and less catchy. "When I started playing out again around '93, I didn't know any other way to do it than to mix it up," Pupp's founder, Prins Thomas, once said. "I was playing stuff from Bitches Brew together with early acid house and Beatles instrumentals." That nobody vaudeville-hooked him off the stage with a cane suggests he was onto something, and in the intervening years, Pupp became known as a place less concerned with the orthodoxy of house and techno than with all the genres that surround them, constellated like stars in playful, inventive ways.10 Years is divided into two mixes edited by Thomas, half old material and half new, blended together. For those who have been paying attention, some of these names will be familiar: Thomas, diskJokke, Blackbelt Andersen, Casiokids, Øyvind Morken, Andre Bratten—none of them besides Thomas having strong individual recognition but all friends at the party, releasing a single or two a year and the occasional album. A few entries—Randaberg Ego Ensemble's "You Can't Do It Right," for example—are by artists who haven't put out anything since 2007, and have only ever released with Full Pupp. The impression here is more of a community than a business, of sly Norwegians twisting out their troubles in the dark.These mixes are good companions. The tempos are closer to walking pace than anything else, and the occasional climax fizzes away like mist. It's slow compared to a lot of techno but rarely feels heavy, in part because it spends a good amount of time laughing. Amidst the serious prog-rock intimations of the void are boing-boing noises and Copacabana beats to remind you that the first thing on their agenda is fun—as is the second and likely the third, if they have not thrown the agenda in the trash by now or gotten it messy with cake. (Todd Terje, who also tends to serve his epiphanies with a joke, released his first singles with Full Pupp, and is missed. Note also that "pupp" in Norwegian means "tit," though what "full tit" means is a question best enjoyed by the imagination.)"If you play within the style of techno than you have to be really good, because there's a lot of really good techno DJs," Thomas once said in an interview, adding, "I'm more like a piano bar entertainer." Like Terje and several of his other peers, Thomas comes off like a goofball who uses self-deprecation to avoid how boring it can be to bear your soul and have others bear theirs to you. His sleight of hand is that he's more clever than he lets on.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 29
#      26 try:
#      27     # have GPT compress the review
#      28     print(f"Compressing reviewId {review_id} with content {review}")
# ---> 29     compressed_review = get_compressed_review(review)
#      30     print(f"Finished compressing reviewId {review_id}: {compressed_review}")
#      32     # parse it
#
# Cell In[16], line 12, in get_compressed_review(review)
#       2 def get_compressed_review(review):
#       3   system_prompt = """You will be given an album review. Read the review and extract any words or phrases that describe the music itself or its emotions/vibes.
#       4
#       5   Your response should be formatted like this:
#    (...)
#       9   EMOTIONS/VIBES: <description of emotions/vibes>
#      10   Do not use full sentences or punctuation."""
# ---> 12   response = openai.ChatCompletion.create(
#      13     model="gpt-3.5-turbo",
#      14     messages=[
#      15           {"role": "system", "content": system_prompt},
#      16           {"role": "user", "content": review},
#      17       ],
#      18     temperature=0.6,
#      19     max_tokens=256
#      20   )
#      22   return response.choices[0].message.content
#
# File ~/Library/Python/3.9/lib/python/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/Library/Python/3.9/lib/python/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/Library/Python/3.9/lib/python/site-packages/openai/api_requestor.py:216, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#     219         params=params,
#     220         supplied_headers=headers,
#     221         files=files,
#     222         stream=stream,
#     223         request_id=request_id,
#     224         request_timeout=request_timeout,
#     225     )
#     226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File ~/Library/Python/3.9/lib/python/site-packages/openai/api_requestor.py:516, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514     _thread_context.session = _make_session()
#     515 try:
# --> 516     result = _thread_context.session.request(
#     517         method,
#     518         abs_url,
#     519         headers=headers,
#     520         data=data,
#     521         files=files,
#     522         stream=stream,
#     523         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     524         proxies=_thread_context.session.proxies,
#     525     )
#     526 except requests.exceptions.Timeout as e:
#     527     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# make embeddings of the concatenated version of compressed reviews and save in Chroma
conn = sqlite3.connect(SQLITE_DB_NAME)
cursor = conn.cursor()

# load concatenated review text
cursor.execute("SELECT reviewId FROM compressed_content")
rows = cursor.fetchall()

documents = []
ids = []
metadatas = []


# pass into Chroma - with persist option
# wrap in for loop - chunks
    # persist at end of loop
openai_ef = embedding_functions.OpenAIEmbeddingFunction(
    api_key=OPENAI_API_KEY,
    model_name=EMBEDDING_MODEL)

client = chromadb.Client(
    Settings(chroma_db_impl="duckdb+parquet",
             persist_directory="embeddings_data"))

collection = client.get_or_create_collection(name="reviews", embedding_function=openai_ef)
